# %%
#уровень 0
#Посчитайте значение первой и второй производной функции:
#f(x) = x^5 + 4sin(2x) + cos(3x+3)
#В точке x = 1.

import numpy as np
import scipy.misc as scp


def f(x) :
    return x**5 + 4*np.sin(2*x) + np.cos(3*x + 3)

x = 1.0
print("Первая производная: " + str(scp.derivative(f, x, n = 1)))
print("Вторая производная: " + str(scp.derivative(f, x, n = 2)))
# Out:
# Первая производная: 14.525826126742029
# Вторая производная: 15.87694727237698

# %%
#Уровень 1
#Постройте график первой и второй производной функции:
#f(x) = sin^5(2x+1)
#На отрезке [-5; 5].

import matplotlib.pyplot as plt

def f(x):
    return (np.sin(2*x + 1))**5

axiesX = np.linspace(-5, 5, num = 50)
#точками
plt.subplot(121)
for i in range(0, len(axiesX), 1):
    f1 = scp.derivative(f, axiesX[i], n = 1)
    f2 = scp.derivative(f, axiesX[i], n = 2)    
    plt.plot(axiesX[i],f1,'o')
    plt.plot(axiesX[i],f2,'b*')

#линиями
plt.subplot(122)
f1 = scp.derivative(f, axiesX, n = 1)
f2 = scp.derivative(f, axiesX, n = 2)
plt.plot(axiesX,f1,'b--')
plt.plot(axiesX,f2,'r-.')
